# %%
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import tqdm

# %%
df = pd.read_parquet('data/processed/march22-24_top200_withalloc_and_augm/test/e2273.parquet')
dates_range={}
dates_range['start'] = pd.to_datetime(df['date'].min())
dates_range['end'] =  pd.to_datetime(df['date'].max())
print(dates_range['start'], dates_range['end']) #TODO check saving files - they are from 11pm to 11pm
# Out:
# 2023-03-21 23:00:00 2023-03-23 23:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2881 entries, 0 to 2880
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        2881 non-null   int64
#  1   power       2881 non-null   float64
#  2   cpu1        2881 non-null   float64
#  3   cpu2        2881 non-null   float64
#  4   cpus_alloc  2881 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 112.7 KB

# %%
df.head(5)
# Out:
#                   date  power  cpu1  cpu2  cpus_alloc
# 0  1679439600000000000  188.0  31.0  32.0        48.0
# 1  1679439660000000000  188.0  31.0  32.0        48.0
# 2  1679439720000000000  188.0  30.0  32.0        48.0
# 3  1679439780000000000  188.0  31.0  32.0        48.0
# 4  1679439840000000000  188.0  31.0  32.0        48.0

# %%
dates_range = pd.date_range(start='2023-03-22', end='2023-03-24', freq='1min', tz='Europe/Warsaw') #shift of 2 hours
print(len(dates_range))

fig = make_subplots(rows=4, cols=1)

for i, col in enumerate(['power', 'cpu1', 'cpu2', 'cpus_alloc']):
    print(i, col)
    fig.add_trace(go.Scatter(x = dates_range, y = df[col], mode='lines', name=col), row=i+1, col=1)

fig.show()
# Out:
# 2881
# 0 power
# 1 cpu1
# 2 cpu2
# 3 cpus_alloc
# ...
